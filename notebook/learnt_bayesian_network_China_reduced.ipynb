# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pgmpy.estimators import PC
from pgmpy.models import BayesianNetwork
from sklearn.model_selection import train_test_split

# %%
covid_policies_df = pd.read_csv(
    "../Final_Data_Combined.csv", index_col=0
)
print(covid_policies_df.shape)
covid_policies_df.head()
# Out:
# (23860, 17)
#   Country        Date school_closures workplace_closures cancel_public_events  \
# 0   China  2020-05-02              2G                 1G                   1G
# 1   China  2020-05-03              2G                 1G                   1G
# 2   China  2020-05-04              2G                 1G                   1G
# 3   China  2020-05-05              2G                 1G                   1G
# 4   China  2020-05-06              2G                 1G                   1G
#
#   restrict_public_gathering closure_public_transport SHN_requirement  \
# 0                        3G                        0               0
# 1                        3G                        0               0
# 2                        3G                        0               0
# 3                        3G                        0               0
# 4                        3G                        0               0
#
#   restriction_internal_movement  internation_travel_control PI_Campaign  \
# 0                            1G                         4.0          2G
# 1                            1G                         4.0          2G
# 2                            1G                         4.0          2G
# 3                            1G                         4.0          2G
# 4                            1G                         4.0          2G
#
#    testing_policy  contact_tracing Facial_Covering Vaccine_policy  \
# 0             3.0              2.0              2G              0
# 1             3.0              2.0              2G              0
# 2             3.0              2.0              2G              0
# 3             3.0              2.0              2G              0
# 4             3.0              2.0              2G              0
#
#    Confirmed_cases  Confirmed_Deathes
# 0            991.0                6.0
# 1            991.0                6.0
# 2            991.0                6.0
# 3            991.0                6.0
# 4            991.0                6.0

# %% [markdown]
# #### Preprocessing

# %%
covid_policies_df["date"] = pd.to_datetime(covid_policies_df["Date"])
covid_policies_df["Country"] = covid_policies_df["Country"].str.lower()
covid_policies_df["Country"] = covid_policies_df["Country"].str.replace(" ", "_")
covid_policies_df.rename(columns={"Country": "country"}, inplace=True)
covid_policies_df.set_index(["country", "date"], inplace=True)
covid_policies_df.drop(columns=["Date"], inplace=True)
covid_policies_df.rename(
    columns={col: col.lower() for col in covid_policies_df.columns}, inplace=True
)
print(covid_policies_df.shape)
covid_policies_df.head()
# Out:
# (23860, 15)
#                    school_closures workplace_closures cancel_public_events  \
# country date
# china   2020-05-02              2G                 1G                   1G
#         2020-05-03              2G                 1G                   1G
#         2020-05-04              2G                 1G                   1G
#         2020-05-05              2G                 1G                   1G
#         2020-05-06              2G                 1G                   1G
#
#                    restrict_public_gathering closure_public_transport  \
# country date
# china   2020-05-02                        3G                        0
#         2020-05-03                        3G                        0
#         2020-05-04                        3G                        0
#         2020-05-05                        3G                        0
#         2020-05-06                        3G                        0
#
#                    shn_requirement restriction_internal_movement  \
# country date
# china   2020-05-02               0                            1G
#         2020-05-03               0                            1G
#         2020-05-04               0                            1G
#         2020-05-05               0                            1G
#         2020-05-06               0                            1G
#
#                     internation_travel_control pi_campaign  testing_policy  \
# country date
# china   2020-05-02                         4.0          2G             3.0
#         2020-05-03                         4.0          2G             3.0
#         2020-05-04                         4.0          2G             3.0
#         2020-05-05                         4.0          2G             3.0
#         2020-05-06                         4.0          2G             3.0
#
#                     contact_tracing facial_covering vaccine_policy  \
# country date
# china   2020-05-02              2.0              2G              0
#         2020-05-03              2.0              2G              0
#         2020-05-04              2.0              2G              0
#         2020-05-05              2.0              2G              0
#         2020-05-06              2.0              2G              0
#
#                     confirmed_cases  confirmed_deathes
# country date
# china   2020-05-02            991.0                6.0
#         2020-05-03            991.0                6.0
#         2020-05-04            991.0                6.0
#         2020-05-05            991.0                6.0
#         2020-05-06            991.0                6.0

# %%
for column in covid_policies_df.columns:
    if pd.api.types.is_numeric_dtype(covid_policies_df[column].dtype):
        continue

    covid_policies_df[column] = (
        covid_policies_df[column].apply(lambda v: v[:1]).astype("int16")
    )

display(covid_policies_df.info())
covid_policies_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 23860 entries, ('china', Timestamp('2020-05-02 00:00:00')) to ('singapore', Timestamp('2022-02-27 00:00:00'))
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   school_closures                23860 non-null  int16
#  1   workplace_closures             23860 non-null  int16
#  2   cancel_public_events           23860 non-null  int16
#  3   restrict_public_gathering      23860 non-null  int16
#  4   closure_public_transport       23860 non-null  int16
#  5   shn_requirement                23860 non-null  int16
#  6   restriction_internal_movement  23860 non-null  int16
#  7   internation_travel_control     23860 non-null  float64
#  8   pi_campaign                    23860 non-null  int16
#  9   testing_policy                 23860 non-null  float64
#  10  contact_tracing                23860 non-null  float64
#  11  facial_covering                23860 non-null  int16
#  12  vaccine_policy                 23860 non-null  int16
#  13  confirmed_cases                23860 non-null  float64
#  14  confirmed_deathes              23860 non-null  float64
# dtypes: float64(5), int16(10)
# memory usage: 1.5+ MB
# None
#                     school_closures  workplace_closures  cancel_public_events  \
# country date
# china   2020-05-02                2                   1                     1
#         2020-05-03                2                   1                     1
#         2020-05-04                2                   1                     1
#         2020-05-05                2                   1                     1
#         2020-05-06                2                   1                     1
#
#                     restrict_public_gathering  closure_public_transport  \
# country date
# china   2020-05-02                          3                         0
#         2020-05-03                          3                         0
#         2020-05-04                          3                         0
#         2020-05-05                          3                         0
#         2020-05-06                          3                         0
#
#                     shn_requirement  restriction_internal_movement  \
# country date
# china   2020-05-02                0                              1
#         2020-05-03                0                              1
#         2020-05-04                0                              1
#         2020-05-05                0                              1
#         2020-05-06                0                              1
#
#                     internation_travel_control  pi_campaign  testing_policy  \
# country date
# china   2020-05-02                         4.0            2             3.0
#         2020-05-03                         4.0            2             3.0
#         2020-05-04                         4.0            2             3.0
#         2020-05-05                         4.0            2             3.0
#         2020-05-06                         4.0            2             3.0
#
#                     contact_tracing  facial_covering  vaccine_policy  \
# country date
# china   2020-05-02              2.0                2               0
#         2020-05-03              2.0                2               0
#         2020-05-04              2.0                2               0
#         2020-05-05              2.0                2               0
#         2020-05-06              2.0                2               0
#
#                     confirmed_cases  confirmed_deathes
# country date
# china   2020-05-02            991.0                6.0
#         2020-05-03            991.0                6.0
#         2020-05-04            991.0                6.0
#         2020-05-05            991.0                6.0
#         2020-05-06            991.0                6.0

# %%
country_to_population_map = {
    "hong_kong": 7500000,
    "china": 1448000000,
    "indonesia": 272000000,
    "singapore": 5450000,
    "malaysia": 32000000,
}

# %%
def compute_cases_bin(cases_per_mil):
    computed_bin = None
    if cases_per_mil <= 10000:
        computed_bin = 0
    elif cases_per_mil < 30000:
        computed_bin = 1
    elif cases_per_mil < 50000:
        computed_bin = 2
    elif cases_per_mil < 70000:
        computed_bin = 3
    elif cases_per_mil < 100000:
        computed_bin = 4
    elif cases_per_mil < 120000:
        computed_bin = 5
    else:
        computed_bin = 6

    return computed_bin

covid_policies_df["cases_per_mil"] = covid_policies_df.apply(lambda row: (row.confirmed_cases * 1000000)/ country_to_population_map[row.name[0]], axis=1)
covid_policies_df["cases_per_mil_cat"] = covid_policies_df["cases_per_mil"].apply(compute_cases_bin)
print(covid_policies_df.shape)
covid_policies_df.head()
# Out:
# (23860, 17)
#                     school_closures  workplace_closures  cancel_public_events  \
# country date
# china   2020-05-02                2                   1                     1
#         2020-05-03                2                   1                     1
#         2020-05-04                2                   1                     1
#         2020-05-05                2                   1                     1
#         2020-05-06                2                   1                     1
#
#                     restrict_public_gathering  closure_public_transport  \
# country date
# china   2020-05-02                          3                         0
#         2020-05-03                          3                         0
#         2020-05-04                          3                         0
#         2020-05-05                          3                         0
#         2020-05-06                          3                         0
#
#                     shn_requirement  restriction_internal_movement  \
# country date
# china   2020-05-02                0                              1
#         2020-05-03                0                              1
#         2020-05-04                0                              1
#         2020-05-05                0                              1
#         2020-05-06                0                              1
#
#                     internation_travel_control  pi_campaign  testing_policy  \
# country date
# china   2020-05-02                         4.0            2             3.0
#         2020-05-03                         4.0            2             3.0
#         2020-05-04                         4.0            2             3.0
#         2020-05-05                         4.0            2             3.0
#         2020-05-06                         4.0            2             3.0
#
#                     contact_tracing  facial_covering  vaccine_policy  \
# country date
# china   2020-05-02              2.0                2               0
#         2020-05-03              2.0                2               0
#         2020-05-04              2.0                2               0
#         2020-05-05              2.0                2               0
#         2020-05-06              2.0                2               0
#
#                     confirmed_cases  confirmed_deathes  cases_per_mil  \
# country date
# china   2020-05-02            991.0                6.0       0.684392
#         2020-05-03            991.0                6.0       0.684392
#         2020-05-04            991.0                6.0       0.684392
#         2020-05-05            991.0                6.0       0.684392
#         2020-05-06            991.0                6.0       0.684392
#
#                     cases_per_mil_cat
# country date
# china   2020-05-02                  0
#         2020-05-03                  0
#         2020-05-04                  0
#         2020-05-05                  0
#         2020-05-06                  0

# %%
covid_policies_df = covid_policies_df.reset_index()

# %%
covid_policies_df.head()
# Out:
#   country       date  school_closures  workplace_closures  \
# 0   china 2020-05-02                2                   1
# 1   china 2020-05-03                2                   1
# 2   china 2020-05-04                2                   1
# 3   china 2020-05-05                2                   1
# 4   china 2020-05-06                2                   1
#
#    cancel_public_events  restrict_public_gathering  closure_public_transport  \
# 0                     1                          3                         0
# 1                     1                          3                         0
# 2                     1                          3                         0
# 3                     1                          3                         0
# 4                     1                          3                         0
#
#    shn_requirement  restriction_internal_movement  internation_travel_control  \
# 0                0                              1                         4.0
# 1                0                              1                         4.0
# 2                0                              1                         4.0
# 3                0                              1                         4.0
# 4                0                              1                         4.0
#
#    pi_campaign  testing_policy  contact_tracing  facial_covering  \
# 0            2             3.0              2.0                2
# 1            2             3.0              2.0                2
# 2            2             3.0              2.0                2
# 3            2             3.0              2.0                2
# 4            2             3.0              2.0                2
#
#    vaccine_policy  confirmed_cases  confirmed_deathes  cases_per_mil  \
# 0               0            991.0                6.0       0.684392
# 1               0            991.0                6.0       0.684392
# 2               0            991.0                6.0       0.684392
# 3               0            991.0                6.0       0.684392
# 4               0            991.0                6.0       0.684392
#
#    cases_per_mil_cat
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
for c in covid_policies_df.country.unique():
    exec(f"df_{c} = covid_policies_df[covid_policies_df.country == \"{c}\"]")
    eval(f"print(\"Size of df_{c}\",df_{c}.shape)")
# Out:
# Size of df_china (21199, 19)
# Size of df_hong_kong (666, 19)
# Size of df_indonesia (667, 19)
# Size of df_malaysia (661, 19)
# Size of df_singapore (667, 19)

# %%
df_china.columns = [f"{col}_China" for col in df_china.columns]
df_malaysia.columns = [f"{col}_Malaysia" for col in df_malaysia.columns]
df_indonesia.columns = [f"{col}_Indonesia" for col in df_indonesia.columns]
df_singapore.columns = [f"{col}_Singapore" for col in df_singapore.columns]
df_hong_kong.columns = [f"{col}_Hong_Kong" for col in df_hong_kong.columns]

# %%
# removing duplicate rows for same date (take max restriction for the specific date)
df_china = df_china.groupby("date_China").max().reset_index()

# %%
m1 = pd.merge(df_china, df_indonesia, left_on = "date_China", right_on = "date_Indonesia")
print(m1.shape)
# Out:
# (667, 38)

# %%
m2 = pd.merge(m1, df_malaysia, left_on = "date_Indonesia", right_on = "date_Malaysia")
print(m2.shape)
# Out:
# (661, 57)

# %%
m3 = pd.merge(m2, df_singapore, left_on = "date_Indonesia", right_on = "date_Singapore")
print(m3.shape)
# Out:
# (661, 76)

# %%
m4 = pd.merge(m3, df_hong_kong, left_on = "date_Indonesia", right_on = "date_Hong_Kong")
print(m4.shape)
# Out:
# (660, 95)

# %%
m4.columns
# Out:
# Index(['date_China', 'country_China', 'school_closures_China',
#        'workplace_closures_China', 'cancel_public_events_China',
#        'restrict_public_gathering_China', 'closure_public_transport_China',
#        'shn_requirement_China', 'restriction_internal_movement_China',
#        'internation_travel_control_China', 'pi_campaign_China',
#        'testing_policy_China', 'contact_tracing_China',
#        'facial_covering_China', 'vaccine_policy_China',
#        'confirmed_cases_China', 'confirmed_deathes_China',
#        'cases_per_mil_China', 'cases_per_mil_cat_China', 'country_Indonesia',
#        'date_Indonesia', 'school_closures_Indonesia',
#        'workplace_closures_Indonesia', 'cancel_public_events_Indonesia',
#        'restrict_public_gathering_Indonesia',
#        'closure_public_transport_Indonesia', 'shn_requirement_Indonesia',
#        'restriction_internal_movement_Indonesia',
#        'internation_travel_control_Indonesia', 'pi_campaign_Indonesia',
#        'testing_policy_Indonesia', 'contact_tracing_Indonesia',
#        'facial_covering_Indonesia', 'vaccine_policy_Indonesia',
#        'confirmed_cases_Indonesia', 'confirmed_deathes_Indonesia',
#        'cases_per_mil_Indonesia', 'cases_per_mil_cat_Indonesia',
#        'country_Malaysia', 'date_Malaysia', 'school_closures_Malaysia',
#        'workplace_closures_Malaysia', 'cancel_public_events_Malaysia',
#        'restrict_public_gathering_Malaysia',
#        'closure_public_transport_Malaysia', 'shn_requirement_Malaysia',
#        'restriction_internal_movement_Malaysia',
#        'internation_travel_control_Malaysia', 'pi_campaign_Malaysia',
#        'testing_policy_Malaysia', 'contact_tracing_Malaysia',
#        'facial_covering_Malaysia', 'vaccine_policy_Malaysia',
#        'confirmed_cases_Malaysia', 'confirmed_deathes_Malaysia',
#        'cases_per_mil_Malaysia', 'cases_per_mil_cat_Malaysia',
#        'country_Singapore', 'date_Singapore', 'school_closures_Singapore',
#        'workplace_closures_Singapore', 'cancel_public_events_Singapore',
#        'restrict_public_gathering_Singapore',
#        'closure_public_transport_Singapore', 'shn_requirement_Singapore',
#        'restriction_internal_movement_Singapore',
#        'internation_travel_control_Singapore', 'pi_campaign_Singapore',
#        'testing_policy_Singapore', 'contact_tracing_Singapore',
#        'facial_covering_Singapore', 'vaccine_policy_Singapore',
#        'confirmed_cases_Singapore', 'confirmed_deathes_Singapore',
#        'cases_per_mil_Singapore', 'cases_per_mil_cat_Singapore',
#        'country_Hong_Kong', 'date_Hong_Kong', 'school_closures_Hong_Kong',
#        'workplace_closures_Hong_Kong', 'cancel_public_events_Hong_Kong',
#        'restrict_public_gathering_Hong_Kong',
#        'closure_public_transport_Hong_Kong', 'shn_requirement_Hong_Kong',
#        'restriction_internal_movement_Hong_Kong',
#        'internation_travel_control_Hong_Kong', 'pi_campaign_Hong_Kong',
#        'testing_policy_Hong_Kong', 'contact_tracing_Hong_Kong',
#        'facial_covering_Hong_Kong', 'vaccine_policy_Hong_Kong',
#        'confirmed_cases_Hong_Kong', 'confirmed_deathes_Hong_Kong',
#        'cases_per_mil_Hong_Kong', 'cases_per_mil_cat_Hong_Kong'],
#       dtype='object')

# %%
# !/home/a/ajayago/.conda/envs/cs5340/bin/pip install ipywidgets
# !/home/a/ajayago/.conda/envs/cs5340/bin/jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ipywidgets in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (7.6.5)
# Requirement already satisfied: nbformat>=4.2.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: ipython>=4.0.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipywidgets) (7.31.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipywidgets) (5.5.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: tornado>=4.2 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: jupyter-client in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.2)
# Requirement already satisfied: jedi>=0.16 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: backcall in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (58.0.4)
# Requirement already satisfied: matplotlib-inline in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.27)
# Requirement already satisfied: pygments in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: decorator in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-core in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (5.4.0)
# Requirement already satisfied: importlib-metadata in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (4.11.1)
# Requirement already satisfied: typing-extensions in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.8)
# Requirement already satisfied: nbconvert in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.4.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: jinja2 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: prometheus-client in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: argon2-cffi in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.1.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.4)
# Requirement already satisfied: pyzmq>=17 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (19.0.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: entrypoints in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: python-dateutil>=2.1 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: defusedxml in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.11)
# Requirement already satisfied: bleach in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: testpath in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: webencodings in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/a/ajayago/.conda/envs/cs5340/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.4)
# Config option `kernel_spec_manager_class` not recognized by `EnableNBExtensionApp`.
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
new_df = m4.drop(["country_Indonesia", "country_Malaysia", "country_Singapore", "country_China", "country_Hong_Kong",\
                 "date_Indonesia", "date_Malaysia", "date_Singapore", "date_China", "date_Hong_Kong", \
                  'confirmed_cases_China', 'confirmed_deathes_China',\
                  'confirmed_cases_Indonesia', 'confirmed_deathes_Indonesia',\
                  'confirmed_cases_Malaysia', 'confirmed_deathes_Malaysia',\
                  'confirmed_cases_Singapore', 'confirmed_deathes_Singapore',\
                 'confirmed_cases_Hong_Kong', 'confirmed_deathes_Hong_Kong', \
                 'cases_per_mil_China', 'cases_per_mil_Indonesia', 'cases_per_mil_Malaysia', 'cases_per_mil_Singapore', 'cases_per_mil_Hong_Kong']\
                 , axis = 1)

# %% [markdown]
# #### Train - Test Split

# %%
x_cols = list(set(new_df.columns) - \
set(["cases_per_mil_cat_Hong_Kong", "cases_per_mil_cat_Singapore", "cases_per_mil_cat_Malaysia", \
     "cases_per_mil_cat_Indonesia", "cases_per_mil_cat_China"]))
y_cols = ["cases_per_mil_cat_Hong_Kong", "cases_per_mil_cat_Singapore", "cases_per_mil_cat_Malaysia", \
     "cases_per_mil_cat_Indonesia", "cases_per_mil_cat_China"]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    new_df[x_cols], new_df[y_cols]
)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (495, 65)
# (165, 65)
# (495, 5)
# (165, 5)

# %% [markdown]
# #### Structure Learning

# %%
est = PC(data=x_train)
estimated_model = est.estimate(variant="stable", max_cond_vars=4) # can change the max_cond_vars value
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
import networkx as nx
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1, figsize=(20,20))
nx.draw(estimated_model, with_labels=True, ax=ax)
plt.tight_layout()

# %% [markdown]
# #### Parameter Estimation

# %%
learnt_bn = BayesianNetwork(list(estimated_model.edges))

# %%
from pgmpy.estimators import MaximumLikelihoodEstimator
learnt_bn.fit(pd.concat([x_train, y_train], axis=1), MaximumLikelihoodEstimator)

# %%
for cpd in learnt_bn.get_cpds():
    print(cpd)
# Out:
# +------------------------------+----------+
# | facial_covering_Indonesia(3) | 0.238384 |
# +------------------------------+----------+
# | facial_covering_Indonesia(4) | 0.761616 |
# +------------------------------+----------+
# +------------------------------+-----+------------------------------+
# | facial_covering_Indonesia    | ... | facial_covering_Indonesia(4) |
# +------------------------------+-----+------------------------------+
# | school_closures_Indonesia(1) | ... | 0.015915119363395226         |
# +------------------------------+-----+------------------------------+
# | school_closures_Indonesia(2) | ... | 0.4350132625994695           |
# +------------------------------+-----+------------------------------+
# | school_closures_Indonesia(3) | ... | 0.5490716180371353           |
# +------------------------------+-----+------------------------------+
# +----------------------------------------+----------+
# | restrict_public_gathering_Hong_Kong(3) | 0.224242 |
# +----------------------------------------+----------+
# | restrict_public_gathering_Hong_Kong(4) | 0.775758 |
# +----------------------------------------+----------+
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# +-----------------------------------+-----+-----------------------------+
# | workplace_closures_China          | ... | workplace_closures_China(3) |
# +-----------------------------------+-----+-----------------------------+
# | closure_public_transport_China(0) | ... | 0.002583979328165375        |
# +-----------------------------------+-----+-----------------------------+
# | closure_public_transport_China(1) | ... | 0.082687338501292           |
# +-----------------------------------+-----+-----------------------------+
# | closure_public_transport_China(2) | ... | 0.9147286821705426          |
# +-----------------------------------+-----+-----------------------------+
# +--------------------------------+-----+
# | closure_public_transport_China | ... |
# +--------------------------------+-----+
# | workplace_closures_China       | ... |
# +--------------------------------+-----+
# | school_closures_China(1)       | ... |
# +--------------------------------+-----+
# | school_closures_China(2)       | ... |
# +--------------------------------+-----+
# | school_closures_China(3)       | ... |
# +--------------------------------+-----+
# +--------------------------------+-----+
# | closure_public_transport_China | ... |
# +--------------------------------+-----+
# | workplace_closures_China       | ... |
# +--------------------------------+-----+
# | facial_covering_China(2)       | ... |
# +--------------------------------+-----+
# | facial_covering_China(3)       | ... |
# +--------------------------------+-----+
# | facial_covering_China(4)       | ... |
# +--------------------------------+-----+
# +-----+----------------------------------+
# | ... | cancel_public_events_Malaysia(2) |
# +-----+----------------------------------+
# | ... | 0.09130434782608696              |
# +-----+----------------------------------+
# | ... | 0.0                              |
# +-----+----------------------------------+
# | ... | 0.908695652173913                |
# +-----+----------------------------------+
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# +-----------------------------------+-----------+
# | cancel_public_events_Indonesia(1) | 0.0606061 |
# +-----------------------------------+-----------+
# | cancel_public_events_Indonesia(2) | 0.939394  |
# +-----------------------------------+-----------+
# +---------------------------------+-----+
# | cancel_public_events_Indonesia  | ... |
# +---------------------------------+-----+
# | restrict_public_gathering_China | ... |
# +---------------------------------+-----+
# | shn_requirement_Hong_Kong(0)    | ... |
# +---------------------------------+-----+
# | shn_requirement_Hong_Kong(1)    | ... |
# +---------------------------------+-----+
# +-----------------------------+-----+--------------------------+
# | shn_requirement_China       | ... | shn_requirement_China(3) |
# +-----------------------------+-----+--------------------------+
# | workplace_closures_China(2) | ... | 0.15350877192982457      |
# +-----------------------------+-----+--------------------------+
# | workplace_closures_China(3) | ... | 0.8464912280701754       |
# +-----------------------------+-----+--------------------------+
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# +-----------------------------+-----+-------------------------------+
# | testing_policy_Indonesia    | ... | testing_policy_Indonesia(3.0) |
# +-----------------------------+-----+-------------------------------+
# | vaccine_policy_China        | ... | vaccine_policy_China(5)       |
# +-----------------------------+-----+-------------------------------+
# | vaccine_policy_Singapore(0) | ... | 0.0                           |
# +-----------------------------+-----+-------------------------------+
# | vaccine_policy_Singapore(1) | ... | 0.0                           |
# +-----------------------------+-----+-------------------------------+
# | vaccine_policy_Singapore(2) | ... | 0.19337016574585636           |
# +-----------------------------+-----+-------------------------------+
# | vaccine_policy_Singapore(4) | ... | 0.3314917127071823            |
# +-----------------------------+-----+-------------------------------+
# | vaccine_policy_Singapore(5) | ... | 0.47513812154696133           |
# +-----------------------------+-----+-------------------------------+
# +-------------------------------+----------+
# | testing_policy_Indonesia(1.0) | 0.634343 |
# +-------------------------------+----------+
# | testing_policy_Indonesia(3.0) | 0.365657 |
# +-------------------------------+----------+
# +-------------------------+----------+
# | pi_campaign_Malaysia(0) | 0.010101 |
# +-------------------------+----------+
# | pi_campaign_Malaysia(2) | 0.989899 |
# +-------------------------+----------+
# +----------------------------+-----+-------------------------+
# | pi_campaign_Malaysia       | ... | pi_campaign_Malaysia(2) |
# +----------------------------+-----+-------------------------+
# | vaccine_policy_Malaysia(0) | ... | 0.4448979591836735      |
# +----------------------------+-----+-------------------------+
# | vaccine_policy_Malaysia(1) | ... | 0.014285714285714285    |
# +----------------------------+-----+-------------------------+
# | vaccine_policy_Malaysia(2) | ... | 0.05714285714285714     |
# +----------------------------+-----+-------------------------+
# | vaccine_policy_Malaysia(3) | ... | 0.03469387755102041     |
# +----------------------------+-----+-------------------------+
# | vaccine_policy_Malaysia(4) | ... | 0.20408163265306123     |
# +----------------------------+-----+-------------------------+
# | vaccine_policy_Malaysia(5) | ... | 0.24489795918367346     |
# +----------------------------+-----+-------------------------+
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# +--------------------------------+-----+
# | cancel_public_events_Singapore | ... |
# +--------------------------------+-----+
# | facial_covering_Malaysia(2)    | ... |
# +--------------------------------+-----+
# | facial_covering_Malaysia(3)    | ... |
# +--------------------------------+-----+
# +-----+------------------------------+
# | ... | facial_covering_Hong_Kong(3) |
# +-----+------------------------------+
# | ... | 0.0                          |
# +-----+------------------------------+
# | ... | 0.4117647058823529           |
# +-----+------------------------------+
# | ... | 0.39215686274509803          |
# +-----+------------------------------+
# | ... | 0.19607843137254902          |
# +-----+------------------------------+
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# +------------------------------+----------+
# | facial_covering_Hong_Kong(1) | 0.133333 |
# +------------------------------+----------+
# | facial_covering_Hong_Kong(2) | 0.763636 |
# +------------------------------+----------+
# | facial_covering_Hong_Kong(3) | 0.10303  |
# +------------------------------+----------+
# +-------------------------------------------+----------+
# | internation_travel_control_Hong_Kong(2.0) | 0.218182 |
# +-------------------------------------------+----------+
# | internation_travel_control_Hong_Kong(3.0) | 0.50101  |
# +-------------------------------------------+----------+
# | internation_travel_control_Hong_Kong(4.0) | 0.280808 |
# +-------------------------------------------+----------+
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# +---------------------------------------+-----------+
# | internation_travel_control_China(2.0) | 0.0020202 |
# +---------------------------------------+-----------+
# | internation_travel_control_China(3.0) | 0.0828283 |
# +---------------------------------------+-----------+
# | internation_travel_control_China(4.0) | 0.915152  |
# +---------------------------------------+-----------+
# +----------------------------------+-----+
# | internation_travel_control_China | ... |
# +----------------------------------+-----+
# | workplace_closures_Singapore(1)  | ... |
# +----------------------------------+-----+
# | workplace_closures_Singapore(2)  | ... |
# +----------------------------------+-----+
# | workplace_closures_Singapore(3)  | ... |
# +----------------------------------+-----+
# +--------------------------------------+-----------+
# | closure_public_transport_Malaysia(0) | 0.492929  |
# +--------------------------------------+-----------+
# | closure_public_transport_Malaysia(1) | 0.452525  |
# +--------------------------------------+-----------+
# | closure_public_transport_Malaysia(2) | 0.0545455 |
# +--------------------------------------+-----------+
# +-----------------------------------+-----+
# | closure_public_transport_Malaysia | ... |
# +-----------------------------------+-----+
# | school_closures_Malaysia(0)       | ... |
# +-----------------------------------+-----+
# | school_closures_Malaysia(1)       | ... |
# +-----------------------------------+-----+
# | school_closures_Malaysia(2)       | ... |
# +-----------------------------------+-----+
# | school_closures_Malaysia(3)       | ... |
# +-----------------------------------+-----+
# +----------------------------------+-----------+
# | cancel_public_events_Malaysia(1) | 0.0707071 |
# +----------------------------------+-----------+
# | cancel_public_events_Malaysia(2) | 0.929293  |
# +----------------------------------+-----------+
# +------------------------------------+----------+
# | restrict_public_gathering_China(3) | 0.040404 |
# +------------------------------------+----------+
# | restrict_public_gathering_China(4) | 0.959596 |
# +------------------------------------+----------+
# +------------------------------+-----------+
# | shn_requirement_Singapore(1) | 0.929293  |
# +------------------------------+-----------+
# | shn_requirement_Singapore(2) | 0.0707071 |
# +------------------------------+-----------+
# +-----+------------------------------+
# | ... | shn_requirement_Singapore(2) |
# +-----+------------------------------+
# | ... | 0.0                          |
# +-----+------------------------------+
# | ... | 1.0                          |
# +-----+------------------------------+
# +--------------------------------------------+----------+
# | restriction_internal_movement_Indonesia(1) | 0.256566 |
# +--------------------------------------------+----------+
# | restriction_internal_movement_Indonesia(2) | 0.743434 |
# +--------------------------------------------+----------+
# +--------------------------+-----------+
# | shn_requirement_China(1) | 0.0565657 |
# +--------------------------+-----------+
# | shn_requirement_China(2) | 0.0222222 |
# +--------------------------+-----------+
# | shn_requirement_China(3) | 0.921212  |
# +--------------------------+-----------+

# %% [markdown]
# #### Inferencing

# %%
test_df = pd.concat([x_test, y_test], axis=1)

# %%
test_df[test_df["closure_public_transport_Malaysia"] == 1][["closure_public_transport_Malaysia", "school_closures_Malaysia"]]
# Out:
#      closure_public_transport_Malaysia  school_closures_Malaysia
# 243                                  1                         3
# 267                                  1                         3
# 498                                  1                         3
# 447                                  1                         3
# 276                                  1                         3
# ..                                 ...                       ...
# 275                                  1                         3
# 289                                  1                         3
# 247                                  1                         3
# 444                                  1                         3
# 375                                  1                         3
#
# [72 rows x 2 columns]

# %%
from pgmpy.inference import VariableElimination

ve = VariableElimination(learnt_bn)

# %%
print(
    ve.query(
        ["school_closures_Malaysia"], evidence={"closure_public_transport_Malaysia": 1}
    )
)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# +-----------------------------+---------------------------------+
# | school_closures_Malaysia    |   phi(school_closures_Malaysia) |
# +=============================+=================================+
# | school_closures_Malaysia(0) |                          0.0000 |
# +-----------------------------+---------------------------------+
# | school_closures_Malaysia(1) |                          0.0000 |
# +-----------------------------+---------------------------------+
# | school_closures_Malaysia(2) |                          0.1964 |
# +-----------------------------+---------------------------------+
# | school_closures_Malaysia(3) |                          0.8036 |
# +-----------------------------+---------------------------------+
